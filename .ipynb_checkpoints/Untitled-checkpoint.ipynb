# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Matplotlib installation also required

# %%
dirty_data = pd.read_csv('./data_clean.csv')

# %%
dirty_data.head()
# Out:
#       Series 1
# 0  2397.167568
# 1  2371.333300
# 2  2573.025408
# 3          NaN
# 4  2574.872476

# %%
dirty_data.plot()
# Out:
# <AxesSubplot:>

# %%
sns.set(rc={'figure.figsize':(20,10)})

# %%
plt.plot(dirty_data)

# %%
# Remove outliers
type(dirty_data)
mean = np.mean(dirty_data)
stdev = np.std(dirty_data)
